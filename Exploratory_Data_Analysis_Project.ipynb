# %% [markdown]
# <a href="https://colab.research.google.com/github/ryhntpl/EDA_Employee_Retention_ML_Project/blob/main/Exploratory_Data_Analysis_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#create dataframe to read dataset

df=pd.read_csv('/content/hr_employee_churn_data.csv')

# %%
#check the dataframe and its data

df.head()
# Out:
#    empid  satisfaction_level  last_evaluation  number_project  \
# 0      1                0.38             0.53               2
# 1      2                0.80             0.86               5
# 2      3                0.11             0.88               7
# 3      4                0.72             0.87               5
# 4      5                0.37             0.52               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   157                   3              0
# 1                   262                   6              0
# 2                   272                   4              0
# 3                   223                   5              0
# 4                   159                   3              0
#
#    promotion_last_5years  salary  left
# 0                      0     low     1
# 1                      0  medium     1
# 2                      0  medium     1
# 3                      0     low     1
# 4                      0     low     1

# %%
# check dataframe structure like columns and its datatypes

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   empid                  14999 non-null  int64
#  1   satisfaction_level     14997 non-null  float64
#  2   last_evaluation        14999 non-null  float64
#  3   number_project         14999 non-null  int64
#  4   average_montly_hours   14999 non-null  int64
#  5   time_spend_company     14999 non-null  int64
#  6   Work_accident          14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   salary                 14999 non-null  object
#  9   left                   14999 non-null  int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 1.1+ MB

# %%
#check the num of rows and columns in dataframe

df.shape
# Out:
# (14999, 10)

# %%
df.describe()
# Out:
#               empid  satisfaction_level  last_evaluation  number_project  \
# count  14999.000000        14997.000000     14999.000000    14999.000000
# mean    7500.000000            0.612863         0.716102        3.803054
# std     4329.982679            0.248634         0.171169        1.232592
# min        1.000000            0.090000         0.360000        2.000000
# 25%     3750.500000            0.440000         0.560000        3.000000
# 50%     7500.000000            0.640000         0.720000        4.000000
# 75%    11249.500000            0.820000         0.870000        5.000000
# max    14999.000000            1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident  \
# count          14999.000000        14999.000000   14999.000000
# mean             201.050337            3.498233       0.144610
# std               49.943099            1.460136       0.351719
# min               96.000000            2.000000       0.000000
# 25%              156.000000            3.000000       0.000000
# 50%              200.000000            3.000000       0.000000
# 75%              245.000000            4.000000       0.000000
# max              310.000000           10.000000       1.000000
#
#        promotion_last_5years          left
# count           14999.000000  14999.000000
# mean                0.021268      0.238083
# std                 0.144281      0.425924
# min                 0.000000      0.000000
# 25%                 0.000000      0.000000
# 50%                 0.000000      0.000000
# 75%                 0.000000      0.000000
# max                 1.000000      1.000000

# %%
df['Work_accident'].unique()
# Out:
# array([0, 1])

# %%
df['promotion_last_5years'].unique()
# Out:
# array([0, 1])

# %%
df.isnull().sum()
# Out:
# empid                    0
# satisfaction_level       2
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# promotion_last_5years    0
# salary                   0
# left                     0
# dtype: int64

# %%
df.head
# Out:
# <bound method NDFrame.head of        empid  satisfaction_level  last_evaluation  number_project  \
# 0          1                0.38             0.53               2
# 1          2                0.80             0.86               5
# 2          3                0.11             0.88               7
# 3          4                0.72             0.87               5
# 4          5                0.37             0.52               2
# ...      ...                 ...              ...             ...
# 14994  14995                0.40             0.57               2
# 14995  14996                0.37             0.48               2
# 14996  14997                0.37             0.53               2
# 14997  14998                0.11             0.96               6
# 14998  14999                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                       157                   3              0
# 1                       262                   6              0
# 2                       272                   4              0
# 3                       223                   5              0
# 4                       159                   3              0
# ...                     ...                 ...            ...
# 14994                   151                   3              0
# 14995                   160                   3              0
# 14996                   143                   3              0
# 14997                   280                   4              0
# 14998                   158                   3              0
#
#        promotion_last_5years  salary  left
# 0                          0     low     1
# 1                          0  medium     1
# 2                          0  medium     1
# 3                          0     low     1
# 4                          0     low     1
# ...                      ...     ...   ...
# 14994                      0     low     1
# 14995                      0     low     1
# 14996                      0     low     1
# 14997                      0     low     1
# 14998                      0     low     1
#
# [14999 rows x 10 columns]>

# %%
# check total employee range based on target column that left

sns.countplot(x='left' ,data=df)
plt.show()

# Take-away: in the training set, Less people left than did'nt.İt seems there is data imbalance..

# %%
# feature 'salary'
sns.countplot(x='salary' ,data=df)
plt.show()

# %%
# feature 'left' split over the feature 'salary'
sns.catplot(x='left', col='salary', kind= 'count', data=df);

#Take-away: it seem low salaried employees have high churning rate

# %%
# feature 'promotion_las_5years'

sns.countplot(x='promotion_last_5years' ,data=df)
plt.show()

#take-away: non promoted employee count is high

# %%
# feature 'left' split over the feature 'promotion_last_5years'
#fig=plt.figure(figsize)=(15,7)
sns.catplot(x='left', col='promotion_last_5years', kind='count' , data=df);

#take-away:it seems non promoted people left more

# %%
# feature 'Work_accident'

sns.countplot(x='Work_accident', data=df)

#take-away: have lss people who made work_accident
# Out:
# <AxesSubplot:xlabel='Work_accident', ylabel='count'>

# %%
#feature 'left' split over the feature 'Work_accident'
#fig=plt.figure(figsize)=(15,7)
sns.catplot(x='left', col='Work_accident', kind='count' , data=df);

#take-away: it seems people left more who did not made accident...we can say it is less important feature

# %%
# satisfation_level :plot a univariate distribution of observations

sns.displot(df['satisfaction_level'])

#take-away: satisfaction_level distributed from 0.1 to 1 where it has high count at 0.1

# %%
#box plot to show distributions with respect to categories

sns.boxplot(x='left', y='satisfaction_level' , data=df)

#take-away:employee left most who has less satisfaction level range 0.2  to 0.5
# Out:
# <AxesSubplot:xlabel='left', ylabel='satisfaction_level'>

# %%
# number_project: plot a univariate distribution of observation

sns.displot(df['number_project'])

#take-away:number_project distributed from 2 to 7 where it has high count at 4

# %%
#box plot to show distributions with respect to categories

sns.boxplot(x='left', y='number_project' , data=df)

#take-away:employee left when number_project count high 4-6 and employee retain who has number_project between 3-4
# Out:
# <AxesSubplot:xlabel='left', ylabel='number_project'>

# %%
# last_evaluation: plot a univariate distribution of observations

sns.displot(df['last_evaluation'])

#take-away:last_evaluation distributed from 0.5 to 1 where it has high count at around 0.55

# %%
#box plot to show distributions with respect to categories

sns.boxplot(x='left', y='last_evaluation' , data=df)

#take-away:not much impact but employee left who has high last_evaluation value
# Out:
# <AxesSubplot:xlabel='left', ylabel='last_evaluation'>

# %%
# average_montly_hours: plot a univariate distribution of observations

sns.displot(df['average_montly_hours'])

#take-away:average_montly_hours distributed from 100 to 300 where it has high count at around 150

# %%
#box plot to show distributions with respect to categories

sns.boxplot(x='left', y='average_montly_hours' , data=df)

#take-away: employee left who has high average_montly_hours value
# Out:
# <AxesSubplot:xlabel='left', ylabel='average_montly_hours'>

# %%
# time_spend_company: plot a univariate distribution of observations

sns.displot(df['time_spend_company'])

#take-away:time_spend_companydistributed from 2 to 10 where it has high count at around 3 and low at 9

# %%
#box plot to show distributions with respect to categories

sns.boxplot(x='left', y='time_spend_company' , data=df)

#take-away: employee left who has high time_spend_company value..
# Out:
# <AxesSubplot:xlabel='left', ylabel='time_spend_company'>

# %%
## checking for correlation

cor_mat=df.corr()
fig=plt.figure(figsize=(15,7))
sns.heatmap(cor_mat,annot=True)
# Out:
# <AxesSubplot:>

# %%
## checking for pairplot

sns.pairplot(df)
